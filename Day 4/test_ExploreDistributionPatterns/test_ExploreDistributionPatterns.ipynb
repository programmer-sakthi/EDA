# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
orders=pd.read_csv("DA314_S4_OrderDetails_Data_Concept.csv")
print(orders.head())

# %%
#Histogram

plt.hist(orders['total_amount'] , bins = 10 , edgecolor = 'black' , color = '#a5daf0')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.title('Histogram of Amounts')
plt.show()

# %%
#KDE Plot

sns.kdeplot(data=orders, x='total_amount' , fill=True , edgecolor='#ffc357' , color='#ffc357')
plt.show()

# %%
#Box plot 

# Box Plot for city vs delivery time
plt.figure(figsize=(10,6))
sns.boxplot(x='city_user', y='delivery_time_min', data=orders , palette='Greens' , hue='city_user')
plt.title('Box Plot for City vs Delivery Time')
plt.xlabel('City')
plt.ylabel('Delivery Time (in minutes)')


plt.show()
