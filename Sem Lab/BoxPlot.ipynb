# %%
# Part A question
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DA314_S8_EmployeeAttrition_Data_Practice.csv')

# %%
# box plot for outlier detection in performance rating
sns.boxplot(df['PerformanceRating'],orient='h')
plt.title("Outlier Detection in Perfromance Rating")
# Out:
# Text(0.5, 1.0, 'Outlier Detection in Perfromance Rating')
